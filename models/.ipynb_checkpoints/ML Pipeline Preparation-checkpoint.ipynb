# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
import nltk
nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
# Out:
# [nltk_data] Downloading package punkt to /Users/zhili/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/zhili/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/zhili/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# import libraries
import re
import pandas as pd
import numpy as np
import pickle
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import pprint

# %%
# load data from database
engine = create_engine('sqlite:///../data/DisasterResponse.db')
df = pd.read_sql_table('DisasterTable',engine)
X = df['message']
y = df.iloc[:,4:]
category_names = y.columns

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
def tokenize(text):
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('Vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier(n_estimators=10))),
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 42)

# train classifier
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('Vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenize at...
#                  MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                                         class_weight=None,
#                                                                         criterion='gini',
#                                                                         max_depth=None,
#                                                                         max_features='auto',
#                                                                         max_leaf_nodes=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split=None,
#                                                                         min_samples_leaf=1,
#                                                                         min_samples_split=2,
#                                                                         min_weight_fraction_leaf=0.0,
#                                                                         n_estimators=10,
#                                                                         n_jobs=None,
#                                                                         oob_score=False,
#                                                                         random_state=None,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                        n_jobs=None))],
#          verbose=False)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
# predict on test data
y_pred = pipeline.predict(X_test)

# %%
# calculate f1 score, precision, recall, and accuracy_score for each output category of dataset
for i in range(len(category_names)):
        print("Category:", category_names[i],"\n", classification_report(y_test.iloc[:, i].values, y_pred[:, i]))
        print('Accuracy of %25s: %.2f\n\n' %(category_names[i], accuracy_score(y_test.iloc[:, i].values, y_pred[:,i])))
# Out:
# Category: related
#                precision    recall  f1-score   support
#
#            0       0.61      0.34      0.44      2054
#            1       0.81      0.93      0.87      6534
#            2       0.45      0.08      0.13        64
#
#     accuracy                           0.78      8652
#    macro avg       0.63      0.45      0.48      8652
# weighted avg       0.76      0.78      0.76      8652
#
# Accuracy of                   related: 0.78
#
#
# Category: request
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      7180
#            1       0.83      0.37      0.51      1472
#
#     accuracy                           0.88      8652
#    macro avg       0.86      0.68      0.72      8652
# weighted avg       0.88      0.88      0.86      8652
#
# Accuracy of                   request: 0.88
#
#
# Category: offer
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8614
#            1       0.00      0.00      0.00        38
#
#     accuracy                           1.00      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.99      1.00      0.99      8652
#
# Accuracy of                     offer: 1.00
#
#
# Category: aid_related
#                precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79      5107
#            1       0.74      0.52      0.61      3545
#
#     accuracy                           0.73      8652
#    macro avg       0.73      0.70      0.70      8652
# weighted avg       0.73      0.73      0.72      8652
#
# Accuracy of               aid_related: 0.73
#
#
# Category: medical_help
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7951
#            1       0.56      0.05      0.09       701
#
#     accuracy                           0.92      8652
#    macro avg       0.74      0.52      0.52      8652
# weighted avg       0.89      0.92      0.89      8652
#
# Accuracy of              medical_help: 0.92
#
#
# Category: medical_products
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8206
#            1       0.58      0.06      0.11       446
#
#     accuracy                           0.95      8652
#    macro avg       0.77      0.53      0.54      8652
# weighted avg       0.93      0.95      0.93      8652
#
# Accuracy of          medical_products: 0.95
#
#
# Category: search_and_rescue
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      8426
#            1       0.67      0.02      0.03       226
#
#     accuracy                           0.97      8652
#    macro avg       0.82      0.51      0.51      8652
# weighted avg       0.97      0.97      0.96      8652
#
# Accuracy of         search_and_rescue: 0.97
#
#
# Category: security
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8492
#            1       0.00      0.00      0.00       160
#
#     accuracy                           0.98      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.96      0.98      0.97      8652
#
# Accuracy of                  security: 0.98
#
#
# Category: military
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8385
#            1       0.53      0.07      0.13       267
#
#     accuracy                           0.97      8652
#    macro avg       0.75      0.54      0.56      8652
# weighted avg       0.96      0.97      0.96      8652
#
# Accuracy of                  military: 0.97
#
#
# Category: child_alone
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8652
#
#     accuracy                           1.00      8652
#    macro avg       1.00      1.00      1.00      8652
# weighted avg       1.00      1.00      1.00      8652
#
# Accuracy of               child_alone: 1.00
#
#
# Category: water
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8109
#            1       0.81      0.15      0.26       543
#
#     accuracy                           0.94      8652
#    macro avg       0.88      0.58      0.61      8652
# weighted avg       0.94      0.94      0.93      8652
#
# Accuracy of                     water: 0.94
#
#
# Category: food
#                precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      7687
#            1       0.85      0.31      0.46       965
#
#     accuracy                           0.92      8652
#    macro avg       0.88      0.65      0.71      8652
# weighted avg       0.91      0.92      0.90      8652
#
# Accuracy of                      food: 0.92
#
#
# Category: shelter
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7877
#            1       0.76      0.10      0.18       775
#
#     accuracy                           0.92      8652
#    macro avg       0.84      0.55      0.57      8652
# weighted avg       0.90      0.92      0.89      8652
#
# Accuracy of                   shelter: 0.92
#
#
# Category: clothing
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8525
#            1       0.80      0.03      0.06       127
#
#     accuracy                           0.99      8652
#    macro avg       0.89      0.52      0.53      8652
# weighted avg       0.98      0.99      0.98      8652
#
# Accuracy of                  clothing: 0.99
#
#
# Category: money
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8461
#            1       0.80      0.04      0.08       191
#
#     accuracy                           0.98      8652
#    macro avg       0.89      0.52      0.53      8652
# weighted avg       0.97      0.98      0.97      8652
#
# Accuracy of                     money: 0.98
#
#
# Category: missing_people
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8548
#            1       0.00      0.00      0.00       104
#
#     accuracy                           0.99      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.98      0.99      0.98      8652
#
# Accuracy of            missing_people: 0.99
#
#
# Category: refugees
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8359
#            1       0.00      0.00      0.00       293
#
#     accuracy                           0.97      8652
#    macro avg       0.48      0.50      0.49      8652
# weighted avg       0.93      0.97      0.95      8652
#
# Accuracy of                  refugees: 0.97
#
#
# Category: death
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8246
#            1       0.76      0.13      0.22       406
#
#     accuracy                           0.96      8652
#    macro avg       0.86      0.56      0.60      8652
# weighted avg       0.95      0.96      0.94      8652
#
# Accuracy of                     death: 0.96
#
#
# Category: other_aid
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      7513
#            1       0.55      0.03      0.06      1139
#
#     accuracy                           0.87      8652
#    macro avg       0.71      0.51      0.49      8652
# weighted avg       0.83      0.87      0.81      8652
#
# Accuracy of                 other_aid: 0.87
#
#
# Category: infrastructure_related
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97      8084
#            1       0.50      0.01      0.01       568
#
#     accuracy                           0.93      8652
#    macro avg       0.72      0.50      0.49      8652
# weighted avg       0.91      0.93      0.90      8652
#
# Accuracy of    infrastructure_related: 0.93
#
#
# Category: transport
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      8245
#            1       0.60      0.02      0.04       407
#
#     accuracy                           0.95      8652
#    macro avg       0.78      0.51      0.51      8652
# weighted avg       0.94      0.95      0.93      8652
#
# Accuracy of                 transport: 0.95
#
#
# Category: buildings
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8211
#            1       0.68      0.06      0.10       441
#
#     accuracy                           0.95      8652
#    macro avg       0.81      0.53      0.54      8652
# weighted avg       0.94      0.95      0.93      8652
#
# Accuracy of                 buildings: 0.95
#
#
# Category: electricity
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8467
#            1       1.00      0.03      0.05       185
#
#     accuracy                           0.98      8652
#    macro avg       0.99      0.51      0.52      8652
# weighted avg       0.98      0.98      0.97      8652
#
# Accuracy of               electricity: 0.98
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Category: tools
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      8599
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.99      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.99      0.99      0.99      8652
#
# Accuracy of                     tools: 0.99
#
#
# Category: hospitals
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      8567
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.99      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.98      0.99      0.99      8652
#
# Accuracy of                 hospitals: 0.99
#
#
# Category: shops
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8618
#            1       0.00      0.00      0.00        34
#
#     accuracy                           1.00      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.99      1.00      0.99      8652
#
# Accuracy of                     shops: 1.00
#
#
# Category: aid_centers
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8537
#            1       0.00      0.00      0.00       115
#
#     accuracy                           0.99      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.97      0.99      0.98      8652
#
# Accuracy of               aid_centers: 0.99
#
#
# Category: other_infrastructure
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8269
#            1       0.50      0.00      0.01       383
#
#     accuracy                           0.96      8652
#    macro avg       0.73      0.50      0.49      8652
# weighted avg       0.94      0.96      0.93      8652
#
# Accuracy of      other_infrastructure: 0.96
#
#
# Category: weather_related
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      6262
#            1       0.82      0.48      0.61      2390
#
#     accuracy                           0.83      8652
#    macro avg       0.83      0.72      0.75      8652
# weighted avg       0.83      0.83      0.81      8652
#
# Accuracy of           weather_related: 0.83
#
#
# Category: floods
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7959
#            1       0.88      0.27      0.42       693
#
#     accuracy                           0.94      8652
#    macro avg       0.91      0.63      0.69      8652
# weighted avg       0.94      0.94      0.92      8652
#
# Accuracy of                    floods: 0.94
#
#
# Category: storm
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      7840
#            1       0.74      0.34      0.47       812
#
#     accuracy                           0.93      8652
#    macro avg       0.84      0.66      0.71      8652
# weighted avg       0.92      0.93      0.91      8652
#
# Accuracy of                     storm: 0.93
#
#
# Category: fire
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8562
#            1       0.00      0.00      0.00        90
#
#     accuracy                           0.99      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.98      0.99      0.98      8652
#
# Accuracy of                      fire: 0.99
#
#
# Category: earthquake
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7865
#            1       0.88      0.64      0.74       787
#
#     accuracy                           0.96      8652
#    macro avg       0.92      0.82      0.86      8652
# weighted avg       0.96      0.96      0.96      8652
#
# Accuracy of                earthquake: 0.96
#
#
# Category: cold
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8465
#            1       0.70      0.11      0.19       187
#
#     accuracy                           0.98      8652
#    macro avg       0.84      0.56      0.59      8652
# weighted avg       0.97      0.98      0.97      8652
#
# Accuracy of                      cold: 0.98
#
#
# Category: other_weather
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8200
#            1       0.65      0.02      0.05       452
#
#     accuracy                           0.95      8652
#    macro avg       0.80      0.51      0.51      8652
# weighted avg       0.93      0.95      0.93      8652
#
# Accuracy of             other_weather: 0.95
#
#
# Category: direct_report
#                precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      6958
#            1       0.77      0.32      0.45      1694
#
#     accuracy                           0.85      8652
#    macro avg       0.81      0.65      0.68      8652
# weighted avg       0.84      0.85      0.82      8652
#
# Accuracy of             direct_report: 0.85

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('Vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                    dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                    lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                    ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                    strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                    tokenizer=<function tokenize at 0x1a232b2488>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                           class_weight=None,
#                                                           criterion='gini',
#                                                           max_depth=None,
#                                                           max_features='auto',
#                                                           max_leaf_nodes=None,
#                                                           min_impurity_decrease=0.0,
#                                                           min_impurity_split=None,
#                                                           min_samples_leaf=1,
#                                                           min_samples_split=2,
#                                                           min_weight_fraction_leaf=0.0,
#                                                           n_estimators=10,
#                                                           n_jobs=None,
#                                                           oob_score=False,
#                                                           random_state=None,
#                                                           verbose=0,
#                                                           warm_start=False),
#                          n_jobs=None))],
#  'verbose': False,
#  'Vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                  dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                  lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                  ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                  strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                  tokenizer=<function tokenize at 0x1a232b2488>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                         class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features='auto',
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         n_estimators=10,
#                                                         n_jobs=None,
#                                                         oob_score=False,
#                                                         random_state=None,
#                                                         verbose=0,
#                                                         warm_start=False),
#                        n_jobs=None),
#  'Vect__analyzer': 'word',
#  'Vect__binary': False,
#  'Vect__decode_error': 'strict',
#  'Vect__dtype': numpy.int64,
#  'Vect__encoding': 'utf-8',
#  'Vect__input': 'content',
#  'Vect__lowercase': True,
#  'Vect__max_df': 1.0,
#  'Vect__max_features': None,
#  'Vect__min_df': 1,
#  'Vect__ngram_range': (1, 1),
#  'Vect__preprocessor': None,
#  'Vect__stop_words': None,
#  'Vect__strip_accents': None,
#  'Vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'Vect__tokenizer': <function __main__.tokenize(text)>,
#  'Vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 10,
#  'clf__estimator__n_jobs': None,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=10,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  'clf__n_jobs': None}

# %%
# Define new feature StartingVerbExtractor
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, x, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %%
model = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ])),

            ('starting_verb', StartingVerbExtractor())
        ])),

        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])

# %%
parameters = {
    'clf__estimator__n_estimators': [10, 40],
    'clf__estimator__min_samples_leaf': [2, 5]
}

cv = GridSearchCV(model,param_grid=parameters)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('features',
#                                         FeatureUnion(n_jobs=None,
#                                                      transformer_list=[('text_pipeline',
#                                                                         Pipeline(memory=None,
#                                                                                  steps=[('vect',
#                                                                                          CountVectorizer(analyzer='word',
#                                                                                                          binary=False,
#                                                                                                          decode_error='strict',
#                                                                                                          dtype=<class 'numpy.int64'>,
#                                                                                                          encoding='utf-8',
#                                                                                                          input='content',
#                                                                                                          lowercase=True,
#                                                                                                          max_df=...
#                                                                                                min_weight_fraction_leaf=0.0,
#                                                                                                n_estimators='warn',
#                                                                                                n_jobs=None,
#                                                                                                oob_score=False,
#                                                                                                random_state=None,
#                                                                                                verbose=0,
#                                                                                                warm_start=False),
#                                                               n_jobs=None))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'clf__estimator__min_samples_leaf': [2, 5],
#                          'clf__estimator__n_estimators': [10, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
y_pred_cv = cv.predict(X_test)

# %%
msg=['Hello I see fire in the street and many houses are destroyed, homeless people everywhere']
test_output = cv.predict(msg)
print(y_train.columns.values[(test_output.flatten()==1)])
# Out:
# ['related' 'aid_related']

# %%
print(cv.best_params_)
# Out:
# {'clf__estimator__min_samples_leaf': 2, 'clf__estimator__n_estimators': 40}

# %%
# calculate f1 score, precision, recall, and accuracy_score for each output category of dataset
for i in range(len(category_names)):
        print("Category:", category_names[i],"\n", classification_report(y_test.iloc[:, i].values, y_pred_cv[:, i]))
        print('Accuracy of %25s: %.2f\n\n' %(category_names[i], accuracy_score(y_test.iloc[:, i].values, y_pred_cv[:,i])))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Category: related
#                precision    recall  f1-score   support
#
#            0       0.76      0.20      0.31      2054
#            1       0.79      0.98      0.87      6534
#            2       0.00      0.00      0.00        64
#
#     accuracy                           0.79      8652
#    macro avg       0.52      0.39      0.40      8652
# weighted avg       0.78      0.79      0.74      8652
#
# Accuracy of                   related: 0.79
#
#
# Category: request
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      7180
#            1       0.94      0.27      0.42      1472
#
#     accuracy                           0.87      8652
#    macro avg       0.90      0.63      0.68      8652
# weighted avg       0.88      0.87      0.84      8652
#
# Accuracy of                   request: 0.87
#
#
# Category: offer
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8614
#            1       0.00      0.00      0.00        38
#
#     accuracy                           1.00      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.99      1.00      0.99      8652
#
# Accuracy of                     offer: 1.00
#
#
# Category: aid_related
#                precision    recall  f1-score   support
#
#            0       0.77      0.87      0.81      5107
#            1       0.76      0.62      0.69      3545
#
#     accuracy                           0.77      8652
#    macro avg       0.77      0.74      0.75      8652
# weighted avg       0.77      0.77      0.76      8652
#
# Accuracy of               aid_related: 0.77
#
#
# Category: medical_help
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7951
#            1       0.77      0.03      0.07       701
#
#     accuracy                           0.92      8652
#    macro avg       0.85      0.52      0.51      8652
# weighted avg       0.91      0.92      0.89      8652
#
# Accuracy of              medical_help: 0.92
#
#
# Category: medical_products
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8206
#            1       0.88      0.02      0.03       446
#
#     accuracy                           0.95      8652
#    macro avg       0.91      0.51      0.50      8652
# weighted avg       0.95      0.95      0.93      8652
#
# Accuracy of          medical_products: 0.95
#
#
# Category: search_and_rescue
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      8426
#            1       1.00      0.00      0.01       226
#
#     accuracy                           0.97      8652
#    macro avg       0.99      0.50      0.50      8652
# weighted avg       0.97      0.97      0.96      8652
#
# Accuracy of         search_and_rescue: 0.97
#
#
# Category: security
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8492
#            1       0.00      0.00      0.00       160
#
#     accuracy                           0.98      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.96      0.98      0.97      8652
#
# Accuracy of                  security: 0.98
#
#
# Category: military
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8385
#            1       0.58      0.03      0.05       267
#
#     accuracy                           0.97      8652
#    macro avg       0.78      0.51      0.52      8652
# weighted avg       0.96      0.97      0.96      8652
#
# Accuracy of                  military: 0.97
#
#
# Category: child_alone
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8652
#
#     accuracy                           1.00      8652
#    macro avg       1.00      1.00      1.00      8652
# weighted avg       1.00      1.00      1.00      8652
#
# Accuracy of               child_alone: 1.00
#
#
# Category: water
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      8109
#            1       0.76      0.02      0.05       543
#
#     accuracy                           0.94      8652
#    macro avg       0.85      0.51      0.51      8652
# weighted avg       0.93      0.94      0.91      8652
#
# Accuracy of                     water: 0.94
#
#
# Category: food
#                precision    recall  f1-score   support
#
#            0       0.90      1.00      0.94      7687
#            1       0.87      0.08      0.14       965
#
#     accuracy                           0.90      8652
#    macro avg       0.88      0.54      0.54      8652
# weighted avg       0.89      0.90      0.86      8652
#
# Accuracy of                      food: 0.90
#
#
# Category: shelter
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7877
#            1       0.79      0.08      0.14       775
#
#     accuracy                           0.92      8652
#    macro avg       0.85      0.54      0.55      8652
# weighted avg       0.91      0.92      0.88      8652
#
# Accuracy of                   shelter: 0.92
#
#
# Category: clothing
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8525
#            1       1.00      0.01      0.02       127
#
#     accuracy                           0.99      8652
#    macro avg       0.99      0.50      0.50      8652
# weighted avg       0.99      0.99      0.98      8652
#
# Accuracy of                  clothing: 0.99
#
#
# Category: money
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8461
#            1       0.00      0.00      0.00       191
#
#     accuracy                           0.98      8652
#    macro avg       0.49      0.50      0.49      8652
# weighted avg       0.96      0.98      0.97      8652
#
# Accuracy of                     money: 0.98
#
#
# Category: missing_people
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8548
#            1       0.00      0.00      0.00       104
#
#     accuracy                           0.99      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.98      0.99      0.98      8652
#
# Accuracy of            missing_people: 0.99
#
#
# Category: refugees
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8359
#            1       0.00      0.00      0.00       293
#
#     accuracy                           0.97      8652
#    macro avg       0.48      0.50      0.49      8652
# weighted avg       0.93      0.97      0.95      8652
#
# Accuracy of                  refugees: 0.97
#
#
# Category: death
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      8246
#            1       1.00      0.03      0.06       406
#
#     accuracy                           0.95      8652
#    macro avg       0.98      0.51      0.52      8652
# weighted avg       0.96      0.95      0.93      8652
#
# Accuracy of                     death: 0.95
#
#
# Category: other_aid
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      7513
#            1       1.00      0.00      0.00      1139
#
#     accuracy                           0.87      8652
#    macro avg       0.93      0.50      0.47      8652
# weighted avg       0.89      0.87      0.81      8652
#
# Accuracy of                 other_aid: 0.87
#
#
# Category: infrastructure_related
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97      8084
#            1       0.00      0.00      0.00       568
#
#     accuracy                           0.93      8652
#    macro avg       0.47      0.50      0.48      8652
# weighted avg       0.87      0.93      0.90      8652
#
# Accuracy of    infrastructure_related: 0.93
#
#
# Category: transport
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      8245
#            1       0.86      0.03      0.06       407
#
#     accuracy                           0.95      8652
#    macro avg       0.91      0.51      0.52      8652
# weighted avg       0.95      0.95      0.93      8652
#
# Accuracy of                 transport: 0.95
#
#
# Category: buildings
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8211
#            1       1.00      0.01      0.01       441
#
#     accuracy                           0.95      8652
#    macro avg       0.97      0.50      0.49      8652
# weighted avg       0.95      0.95      0.93      8652
#
# Accuracy of                 buildings: 0.95
#
#
# Category: electricity
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8467
#            1       0.00      0.00      0.00       185
#
#     accuracy                           0.98      8652
#    macro avg       0.49      0.50      0.49      8652
# weighted avg       0.96      0.98      0.97      8652
#
# Accuracy of               electricity: 0.98
#
#
# Category: tools
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      8599
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.99      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.99      0.99      0.99      8652
# Accuracy of                     tools: 0.99
#
#
# Category: hospitals
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      8567
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.99      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.98      0.99      0.99      8652
#
# Accuracy of                 hospitals: 0.99
#
#
# Category: shops
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8618
#            1       0.00      0.00      0.00        34
#
#     accuracy                           1.00      8652
#    macro avg       0.50      0.50      0.50      8652
# weighted avg       0.99      1.00      0.99      8652
#
# Accuracy of                     shops: 1.00
#
#
# Category: aid_centers
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8537
#            1       0.00      0.00      0.00       115
#
#     accuracy                           0.99      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.97      0.99      0.98      8652
#
# Accuracy of               aid_centers: 0.99
#
#
# Category: other_infrastructure
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8269
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.96      8652
#    macro avg       0.48      0.50      0.49      8652
# weighted avg       0.91      0.96      0.93      8652
#
# Accuracy of      other_infrastructure: 0.96
#
#
# Category: weather_related
#                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      6262
#            1       0.86      0.58      0.69      2390
#
#     accuracy                           0.86      8652
#    macro avg       0.86      0.77      0.80      8652
# weighted avg       0.86      0.86      0.85      8652
#
# Accuracy of           weather_related: 0.86
#
#
# Category: floods
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7959
#            1       0.94      0.22      0.35       693
#
#     accuracy                           0.94      8652
#    macro avg       0.94      0.61      0.66      8652
# weighted avg       0.94      0.94      0.92      8652
#
# Accuracy of                    floods: 0.94
#
#
# Category: storm
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7840
#            1       0.81      0.26      0.39       812
#
#     accuracy                           0.92      8652
#    macro avg       0.87      0.63      0.68      8652
# weighted avg       0.92      0.92      0.91      8652
#
# Accuracy of                     storm: 0.92
#
#
# Category: fire
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      8562
#            1       0.00      0.00      0.00        90
#
#     accuracy                           0.99      8652
#    macro avg       0.49      0.50      0.50      8652
# weighted avg       0.98      0.99      0.98      8652
#
# Accuracy of                      fire: 0.99
#
#
# Category: earthquake
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7865
#            1       0.89      0.59      0.71       787
#
#     accuracy                           0.96      8652
#    macro avg       0.92      0.79      0.84      8652
# weighted avg       0.95      0.96      0.95      8652
#
# Accuracy of                earthquake: 0.96
#
#
# Category: cold
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8465
#            1       1.00      0.02      0.04       187
#
#     accuracy                           0.98      8652
#    macro avg       0.99      0.51      0.52      8652
# weighted avg       0.98      0.98      0.97      8652
#
# Accuracy of                      cold: 0.98
#
#
# Category: other_weather
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8200
#            1       1.00      0.01      0.01       452
#
#     accuracy                           0.95      8652
#    macro avg       0.97      0.50      0.49      8652
# weighted avg       0.95      0.95      0.92      8652
#
# Accuracy of             other_weather: 0.95
#
#
# Category: direct_report
#                precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      6958
#            1       0.91      0.21      0.35      1694
#
#     accuracy                           0.84      8652
#    macro avg       0.87      0.60      0.63      8652
# weighted avg       0.85      0.84      0.80      8652
#
# Accuracy of             direct_report: 0.84

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
filename = 'classifier.pkl'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
